# %%
import sys
import pandas as pd
import numpy as np

# %%
folder = 'drive/MyDrive/'

# %%
mobility = pd.read_csv(folder+'2020_US_Region_Mobility_Report.csv')

# %%
mobility_data = mobility[['country_region', 'retail_and_recreation_percent_change_from_baseline', 'grocery_and_pharmacy_percent_change_from_baseline']]

# %%
mobility_data[0:290][['retail_and_recreation_percent_change_from_baseline']]
# Out:
#      retail_and_recreation_percent_change_from_baseline
# 0                                                  6.0
# 1                                                  7.0
# 2                                                  6.0
# 3                                                  0.0
# 4                                                  2.0
# ..                                                 ...
# 285                                              -70.0
# 286                                              -26.0
# 287                                              -26.0
# 288                                              -23.0
# 289                                                5.0
#
# [290 rows x 1 columns]

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(mobility_data[0:290][['retail_and_recreation_percent_change_from_baseline']])

# %%
plt.plot(mobility_data[0:290][['grocery_and_pharmacy_percent_change_from_baseline']])

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
scaler = MinMaxScaler(feature_range = [-1, 1])
mobility_data[0:290][['grocery_and_pharmacy_percent_change_from_baseline']] = scaler\
    .fit_transform(mobility_data[0:290][['grocery_and_pharmacy_percent_change_from_baseline']].values.reshape(-1,1))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
plt.plot(mobility_data[0:290][['grocery_and_pharmacy_percent_change_from_baseline']])

# %%
mobility_data[0:290][['retail_and_recreation_percent_change_from_baseline']] = scaler\
    .fit_transform(mobility_data[0:290][['retail_and_recreation_percent_change_from_baseline']].values.reshape(-1,1))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /usr/local/lib/python3.6/dist-packages/pandas/core/indexing.py:1734: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(loc, value[:, i].tolist())

# %%
plt.plot(mobility_data[0:290][['retail_and_recreation_percent_change_from_baseline']])

# %%
def mobility_graph(mobility_parameter):
  folder = 'drive/MyDrive/'
  mobility_data = pd.read_csv(folder+'2020_US_Region_Mobility_Report.csv')
  #mobility_data = mobility_data.sort_index(inplace=False, ascending=True)

  scaler = MinMaxScaler(feature_range = [-1, 1])
  mobility_data[[mobility_parameter['attribute']]] = scaler\
    .fit_transform(mobility_data[[mobility_parameter['attribute']]].values.reshape(-1,1))
  
  
  plt.plot(mobility_data[[mobility_parameter['attribute']]], mobility_parameter['color'], label=mobility_parameter['label'])

  plt.xlabel('Days(0-278),(last Nov 23rd)')
 
  
  
  plt.ylabel('Mobility data of '+mobility_parameter['label'])
  plt.title('Plot for '+mobility_parameter['label']+' in US')
  

  plt.figlegend(loc='upper left')

# %%
mobility_parameter = {
    'attribute' : 'retail_and_recreation_percent_change_from_baseline',
    'color' : 'green',
    'label' : 'Retail mobility'
}

mobility_graph(mobility_parameter)

# %%
mobility_parameter = {
    'attribute' : 'grocery_and_pharmacy_percent_change_from_baseline',
    'color' : 'red',
    'label' : 'Grocery and Pharmacies mobility'
}

mobility_graph(mobility_parameter)
